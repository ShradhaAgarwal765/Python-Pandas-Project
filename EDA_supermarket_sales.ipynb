# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('dataset/supermaket_sales.csv', parse_dates=['Date'])
df1['Date'] = pd.to_datetime(df1['Date'], errors = 'coerce')
df1
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df1.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480        NaT
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df1.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675        NaT  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900 2019-03-02  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320 2019-02-09  13:22     Cash
# 998       65.82         1   3.2910    69.1110        NaT  15:33     Cash
# 999       88.34         7  30.9190   649.2990        NaT  13:28     Cash
#
# ...

# %%
df1.sample(5)
# Out:
#       Invoice ID Branch      City Customer type  Gender  \
# 895  699-88-1972      B  Mandalay        Normal    Male
# 124  268-27-6179      B  Mandalay        Member  Female
# 558  712-39-0363      A    Yangon        Member    Male
# 330  868-81-1752      B  Mandalay        Normal    Male
# 454  187-83-5490      A    Yangon        Member    Male
#
#                Product line  Unit price  Quantity  Tax 5%    Total       Date  \
# 895       Health and beauty       99.16         8  39.664  832.944        NaT
# 124     Fashion accessories       56.47         8  22.588  474.348 2019-03-09
# 558      Food and beverages       41.66         6  12.498  262.458 2019-01-02
# 330      Home and lifestyle       22.02         9   9.909  208.089 2019-02-07
# 454  Electronic accessories       20.77         4   4.154   87.234        NaT
#
#       Time      Payment    cogs  gross margin percentage  gross income  Rating
# 895  17:47  Credit card  793.28                 4.761905        39.664     4.2
# ...

# %%
df1.shape
# Out:
# (1000, 17)

# %%
print("Number of rows: ", df1.shape[0])
print("Number of columns: ", df1.shape[1])
# Out:
# Number of rows:  1000
# Number of columns:  17

# %%
df1.isnull().sum()
# Out:
# Invoice ID                   0
# Branch                       0
# City                         0
# Customer type                0
# Gender                       0
# Product line                 0
# Unit price                   0
# Quantity                     0
# Tax 5%                       0
# Total                        0
# Date                       587
# Time                         0
# Payment                      0
# cogs                         0
# gross margin percentage      0
# gross income                 0
# Rating                       0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     413 non-null    datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %%
df1.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total  \
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     55.672130     5.510000    15.379369   322.966749
# min      10.080000     1.000000     0.508500    10.678500
# 25%      32.875000     3.000000     5.924875   124.422375
# 50%      55.230000     5.000000    12.088000   253.848000
# 75%      77.935000     8.000000    22.445250   471.350250
# max      99.960000    10.000000    49.650000  1042.650000
# std      26.494628     2.923431    11.708825   245.885335
#
#                                 Date        cogs  gross margin percentage  \
# count                            413  1000.00000             1.000000e+03
# mean   2019-02-07 22:25:51.573849856   307.58738             4.761905e+00
# min              2019-01-01 00:00:00    10.17000             4.761905e+00
# 25%              2019-01-11 00:00:00   118.49750             4.761905e+00
# ...

# %% [raw]
# UNIVARIATE ANALYSIS

# %%
numerical = []
categorical = []
for col in df1:
    if df1[col].nunique() > 10:
        numerical.append(col)
    else:
        categorical.append(col)

# %%
numerical, categorical
# Out:
# (['Invoice ID',
#   'Unit price',
#   'Tax 5%',
#   'Total',
#   'Date',
#   'Time',
#   'cogs',
#   'gross income',
#   'Rating'],
#  ['Branch',
#   'City',
#   'Customer type',
#   'Gender',
#   'Product line',
#   'Quantity',
#   'Payment',
#   'gross margin percentage'])

# %%
sns.countplot(df1['Branch'])
# Out:
# <Axes: xlabel='count', ylabel='Branch'>

# %%
df1.Branch.value_counts().plot(kind='pie',autopct='%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df1.Branch.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Branch'>

# %%
df1.Payment.value_counts().plot(kind='pie', autopct='%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df1.Rating.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.distplot(df1['Rating'])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
sns.distplot(df1['cogs'])
# Out:
# <Axes: xlabel='cogs', ylabel='Density'>

# %%
df1.cogs.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['cogs'].skew()
# Out:
# 0.8925698049581418

# %%
sns.boxplot(df1.cogs)
# Out:
# <Axes: ylabel='cogs'>

# %% [raw]
# BIVARIATE / MULTIVARIATE ANALYSIS

# %%
sns.scatterplot(x=df1['cogs'],y=df1['Rating'])
# Out:
# <Axes: xlabel='cogs', ylabel='Rating'>

# %%
sns.barplot(x=df1['Branch'],y=df1['gross income'])    #Bivariate analysis
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %%
sns.barplot(x=df1['Branch'],y=df1['gross income'], hue=df1.City)     # multivariate analysis
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %%
sns.barplot(x=df1.Gender,y=df1['gross income'])
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %%
sns.barplot(x=df1.Gender,y=df1['gross income'],hue=df1['Customer type'])
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %%
sns.boxplot(x=df1.Gender,y=df1['gross income'])
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %%
sns.boxplot(x=df1.Gender,y=df1['gross income'],hue=df1['Customer type'])
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %%
sns.barplot(x=df1['Product line'],y=df1['gross income'])
plt.xticks(rotation=60)
plt.show()

# %%
sns.barplot(x=df1['Product line'],y=df1['Unit price'])
plt.xticks(rotation=60)
plt.show()

# %%
df1
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
data = pd.crosstab(df1['City'], df1['Payment'])
data
# Out:
# Payment    Cash  Credit card  Ewallet
# City
# Mandalay    110          109      113
# Naypyitaw   124           98      106
# Yangon      110          104      126

# %%
sns.heatmap(data)
# Out:
# <Axes: xlabel='Payment', ylabel='City'>

# %%
df1
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
(df1.groupby('Product line').sum()['Quantity']).plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 (df1.groupby('Product line').sum()['Quantity']).plot(kind='bar')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:3146, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    3141 else:
#    3142     # If we are grouping on categoricals we want unobserved categories to
#    3143     # return zero, rather than the default of NaN which the reindexing in
#    3144     # _agg_general() returns. GH #31422
#    3145     with com.temp_setattr(self, "observed", True):
# -> 3146         result = self._agg_general(
#    3147             numeric_only=numeric_only,
#    3148             min_count=min_count,
#    3149             alias="sum",
#    3150             npfunc=np.sum,
#    3151         )
#    3153     return self._reindex_output(result, fill_value=0)
#
# ...

# %%
days_map = {
    0:'Monday',
    1:'Tuesday',
    2:'Wednesday',
    3:'Thursday',
    4:'Friday',
    5:'Saturday',
    6:'Sunday',
}

# %%
df1['dayofweek'] = df1['Date'].dt.dayofweek.map(days_map)
df1['dayofweek']

# %%
df1['dayofweek'].value_counts().plot(kind='bar')

# %%
map_month = {
    1:'Jan',
    2:'Feb',
    3:'Mar',
}

df1['month'] = df1['Date'].dt.month.map(map_month)
df1['month']

# %%
df1.month.value_counts().plot(kind='bar')
